# %% [markdown]
# # Setup

# %%
import datetime
import dateutil.parser
import json
import pytz  # pip install pytz
import re
import os
import sys
import shutil
import time

# %% [markdown]
# ## Test 1 Entry

# %%
def create_obsidian_entry_from_day_one(import_dir: str, day_one_entry_json: json, export_dir: str='.', tags: list = ['#dayoneimport']):
    """Create an Obsidian entry from a Day One entry and stores it in the folder specified by export_dir.

    Args:
        import_dir (str): folder where the Day One entry is stored and metadata is stored
        day_one_entry_json (json): Day One entry in JSON format
        export_dir (str): folder where the output obsidian file will be stored
        tags (list): list of base tags to add to the obsidian file
    """
    newEntry = []

    # create a title for the entry in format "20210618211541 - Fri Jun 18 2021.md"
    createDate = dateutil.parser.isoparse(day_one_entry_json["creationDate"])
    localDate = createDate.astimezone(
        pytz.timezone(day_one_entry_json["timeZone"])
    )  # It's natural to use our local date/time as reference point, not UTC
    # TODO: check if this works for win32 and macOSX
    newMDfilename = "%s - %s.md" % (localDate.strftime("%Y%m%d%H%M%S"), localDate.strftime("%a %b %d %Y"))
    newJSONfilename = "%s - %s.json" % (localDate.strftime("%Y%m%d%H%M%S"), localDate.strftime("%a %b %d %Y"))

    # --------------- FRONTMATTER ------------------------

    # Add location and date created to the front matter of the MD file 
    location = ""
    for locale in ["placeName", "localityName", "administrativeArea", "country"]:
        try:
            location = "%s, %s" % (location, day_one_entry_json["location"][locale])
        except KeyError:
            pass
    location = location[2:]

    dateCreated = str(createDate)
    coordinates = ""

    frontmatter = (
    """---
- created: """
    + dateCreated
    + """
"""
    )

    if "location" in day_one_entry_json:
        coordinates = (
            str(day_one_entry_json["location"]["latitude"])
            + ","
            + str(day_one_entry_json["location"]["longitude"])
        )
        frontmatter = frontmatter + "- location: [" + coordinates + "]"
    frontmatter = (
    frontmatter
    + """
---
"""
    )
    newEntry.append(frontmatter)

    # --------------- BODY ------------------------

    # Add date as page header, removing time if it's 12 midday as time obviously not read
    if sys.platform == "win32":
        newEntry.append(
            "## %s\n"
            % (
                localDate.strftime("%A, %#d %B %Y at %#I:%M %p").replace(
                    " at 12:00 PM", ""
                ),
            )
        )
    else:
        newEntry.append(
            "## %s\n"
            % (
                localDate.strftime("%A, %-d %B %Y at %-I:%M %p").replace(
                    " at 12:00 PM", ""
                ),
            )
        )  # untested

    # Add body text if it exists (can have the odd blank entry), after some tidying up
    try:
        newText = day_one_entry_json["text"].replace("\\", "")
        newText = newText.replace("\u2028", "\n")
        newText = newText.replace("\u1C6A", "\n\n")

        # update photo references and file names if they exist
        if "photos" in day_one_entry_json:
            # Correct photo links. First we need to rename them. The filename is the md5 code, not the identifier
            # subsequently used in the text. Then we can amend the text to match. Will only to rename on first run
            # through as then, they are all renamed.

            for p in day_one_entry_json["photos"]:
                pfn = os.path.join(import_dir, "photos", "%s.%s" % (p["md5"],p["type"]))
                if os.path.isfile(pfn):
                    newfn = os.path.join(
                        import_dir, "photos", "%s.%s" % (p["identifier"],p["type"])
                    )
                    print("Renaming photo file from %s to %s" % (pfn, newfn))
                    os.rename(pfn, newfn)
                # Now to replace the text to point to the new file 
                newText = re.sub(
                    r"(\!\[\]\(dayone-moment:\/\/)" + p["identifier"] + "(\))",
                    r"![[" + p["identifier"] + "." + p["type"] + "]]",
                    newText,
                )

        # update video references and file names if they exist
        if "videos" in day_one_entry_json: 
            # Correct video links. First we need to rename them. The filename is the md5 code, not the identifier
            # subsequently used in the text. Then we can amend the text to match. Will only to rename on first run
            # through as then, they are all renamed.
            # Need to account for .mov and .mp4 file types (and potentially others)

            for v in day_one_entry_json["videos"]:
                # try .mov extention else try .mp4
                vfn = os.path.join(import_dir, "videos", "%s.%s" % (v["md5"],v["type"]))
                if os.path.isfile(vfn):
                    newfn = os.path.join(
                        import_dir, "videos", "%s.%s" % (v["identifier"],v["type"])
                    )
                    print("Renaming video file from %s to %s" % (vfn, newfn))
                    os.rename(vfn, newfn)

                # Now to replace the text to point to the file in obsidian
                newText = re.sub(
                    r"(\!\[\]\(dayone-moment:\/video\/)" + v["identifier"] + "(\))",
                    r"![[" + v["identifier"] + "." + v["type"] + "]]",
                    newText,
                )
        
        # update audio references and file names if they exist 
        if "audios" in day_one_entry_json: 
            # Correct audio links. First we need to rename them. The filename is the md5 code, not the identifier
            # subsequently used in the text. Then we can amend the text to match. Will only to rename on first run
            # through as then, they are all renamed.
            # Only handles .m4a format (seems to be the only one used by DayOne but not sure)

            for a in day_one_entry_json["audios"]:
                afn = os.path.join(import_dir, "audios", "%s.%s" % (a["md5"],'m4a'))
                if os.path.isfile(afn):
                    newfn = os.path.join(
                        import_dir, "audios", "%s.%s" % (a["identifier"],'m4a')
                    )
                    print("Renaming audio file from %s to %s" % (afn, newfn))
                    os.rename(afn, newfn)

                # Now to replace the text to point to the file in obsidian
                newText = re.sub(
                    r"(\!\[\]\(dayone-moment:\/audio\/)" + a["identifier"] + "(\))",
                    r"![[" + a["identifier"] + "." + 'm4a' + "]]",
                    newText,
                )

        newEntry.append(newText)
    except KeyError:
        pass

    # --------------- BACKMATTER  ------------------------

    newEntry.append("\n\n---\n")

    if location:
        if coordinates == []:
            locationString = location
        else:
            locationString = "[" + location + "](geo:" + coordinates + ")"
        newEntry.append(locationString)

        # Add GPS, not all entries have this
        try:
            newEntry.append( '\n- GPS: [%s, %s](https://www.google.com/maps/search/?api=1&query=%s,%s)\n' % ( day_one_entry_json['location']['latitude'], day_one_entry_json['location']['longitude'], day_one_entry_json['location']['latitude'], day_one_entry_json['location']['longitude'] ) )
        except KeyError:
            pass

    if "tags" in day_one_entry_json:
        tags_to_add = tags 
        for t in day_one_entry_json["tags"]:
            tags_to_add.append(
                "%s%s" % ('#', t.replace(" ", "-").replace("---", "-"))
            )
        if day_one_entry_json["starred"]:
            tags.append("#starred")
    if len(tags) > 0:
        newEntry.append("- Tags: %s\n" % " ".join(tags))

    # Write the new file to a file in the appropriate place
    with open(os.path.join(export_dir, newMDfilename), "w", encoding="utf-8") as f:
        print("Writing obsidian md file %s" % os.path.join(export_dir, newMDfilename))
        for line in newEntry:
            f.write(line)

    # Write out the day one meta data to a json file with the same name
    with open(os.path.join(export_dir, newJSONfilename), "w", encoding="utf-8") as f:
        print("Writing day one json file to %s" % os.path.join(export_dir, newJSONfilename))
        json.dump(day_one_entry_json, f, indent=4)

# %% [markdown]
# # Import Daily Reflections Journal

# %%
# Set this as the location where your Journal.json file is located
root = "/Volumes/External/01-01-2024_9-10-PM"
import_journal = os.path.join(root, 'Daily Reflection.json')

# Set this as the location where you want to export your journal entries
export_journal = os.path.join(root, 'Daily Reflection')

# Create the export folder if it doesn't exist
if not os.path.exists(export_journal):
    os.mkdir(export_journal)

# Read the journal file
with open(import_journal, 'r') as f:
    journal = json.load(f)

print(len(journal['entries']))

# Iterate through the journal entries
for entry in journal['entries']:
    create_obsidian_entry_from_day_one(root, entry, export_journal, tags = ['#dailyjournal', '#dayoneimport'])
    time.sleep(1) # sleep for 1 second to avoid duplicate filenames
# Out:
# 1301
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20181205212413 - Wed Dec 05 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20181205212413 - Wed Dec 05 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20181206233733 - Thu Dec 06 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20181206233733 - Thu Dec 06 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20181206234139 - Thu Dec 06 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20181206234139 - Thu Dec 06 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20181207235538 - Fri Dec 07 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20181207235538 - Fri Dec 07 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20181210221848 - Mon Dec 10 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20181210221848 - Mon Dec 10 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20181212223803 - Wed Dec 12 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20181212223803 - Wed Dec 12 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20181215104629 - Sat Dec 15 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20181215104629 - Sat Dec 15 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20181226102309 - Wed Dec 26 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20181226102309 - Wed Dec 26 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190103211547 - Thu Jan 03 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190103211547 - Thu Jan 03 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190104222541 - Fri Jan 04 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190104222541 - Fri Jan 04 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190107004512 - Mon Jan 07 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190107004512 - Mon Jan 07 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190108001035 - Tue Jan 08 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190108001035 - Tue Jan 08 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190111004842 - Fri Jan 11 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190111004842 - Fri Jan 11 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190114212104 - Mon Jan 14 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190114212104 - Mon Jan 14 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190122105507 - Tue Jan 22 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190122105507 - Tue Jan 22 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190129081512 - Tue Jan 29 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190129081512 - Tue Jan 29 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190202143929 - Sat Feb 02 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190202143929 - Sat Feb 02 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190208210617 - Fri Feb 08 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190208210617 - Fri Feb 08 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190212005114 - Tue Feb 12 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190212005114 - Tue Feb 12 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190216210615 - Sat Feb 16 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190216210615 - Sat Feb 16 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190226213226 - Tue Feb 26 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190226213226 - Tue Feb 26 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190303230658 - Sun Mar 03 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190303230658 - Sun Mar 03 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190327110417 - Wed Mar 27 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190327110417 - Wed Mar 27 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190407215533 - Sun Apr 07 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190407215533 - Sun Apr 07 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190617220822 - Mon Jun 17 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190617220822 - Mon Jun 17 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190721014617 - Sun Jul 21 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190721014617 - Sun Jul 21 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190721014641 - Sun Jul 21 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190721014641 - Sun Jul 21 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190803211217 - Sat Aug 03 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190803211217 - Sat Aug 03 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190824051115 - Sat Aug 24 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20190824051115 - Sat Aug 24 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20191004211426 - Fri Oct 04 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20191004211426 - Fri Oct 04 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20191130004045 - Sat Nov 30 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20191130004045 - Sat Nov 30 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20200107231923 - Tue Jan 07 2020.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20200107231923 - Tue Jan 07 2020.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20200208210945 - Sat Feb 08 2020.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20
2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231126130958 - Sun Nov 26 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231126134515 - Sun Nov 26 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231126134515 - Sun Nov 26 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231126163200 - Sun Nov 26 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231126163200 - Sun Nov 26 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231127081823 - Mon Nov 27 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231127081823 - Mon Nov 27 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231129235808 - Wed Nov 29 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231129235808 - Wed Nov 29 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231129235902 - Wed Nov 29 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231129235902 - Wed Nov 29 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231130235021 - Thu Nov 30 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231130235021 - Thu Nov 30 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231201232350 - Fri Dec 01 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231201232350 - Fri Dec 01 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231202121531 - Sat Dec 02 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231202121531 - Sat Dec 02 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231203121003 - Sun Dec 03 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231203121003 - Sun Dec 03 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231204233446 - Mon Dec 04 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231204233446 - Mon Dec 04 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231208001648 - Fri Dec 08 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231208001648 - Fri Dec 08 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231208001917 - Fri Dec 08 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231208001917 - Fri Dec 08 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231208002600 - Fri Dec 08 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231208002600 - Fri Dec 08 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231210004605 - Sun Dec 10 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231210004605 - Sun Dec 10 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231210005737 - Sun Dec 10 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231210005737 - Sun Dec 10 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231211003258 - Mon Dec 11 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231211003258 - Mon Dec 11 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231212003850 - Tue Dec 12 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231212003850 - Tue Dec 12 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231213003113 - Wed Dec 13 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231213003113 - Wed Dec 13 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231214004912 - Thu Dec 14 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231214004912 - Thu Dec 14 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231216011759 - Sat Dec 16 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231216011759 - Sat Dec 16 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231216012545 - Sat Dec 16 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231216012545 - Sat Dec 16 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231216235855 - Sat Dec 16 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231216235855 - Sat Dec 16 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231218010924 - Mon Dec 18 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231218010924 - Mon Dec 18 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231218202737 - Mon Dec 18 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231218202737 - Mon Dec 18 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231220005024 - Wed Dec 20 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231220005024 - Wed Dec 20 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231220222109 - Wed Dec 20 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231220222109 - Wed Dec 20 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231222215252 - Fri Dec 22 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231222215252 - Fri Dec 22 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231222215651 - Fri Dec 22 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231222215651 - Fri Dec 22 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231225100014 - Mon Dec 25 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231225100014 - Mon Dec 25 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231225101858 - Mon Dec 25 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231225101858 - Mon Dec 25 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231225133524 - Mon Dec 25 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231225133524 - Mon Dec 25 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231226233411 - Tue Dec 26 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231226233411 - Tue Dec 26 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231229010134 - Fri Dec 29 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231229010134 - Fri Dec 29 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231229010703 - Fri Dec 29 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231229010703 - Fri Dec 29 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231229233330 - Fri Dec 29 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231229233330 - Fri Dec 29 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231230094911 - Sat Dec 30 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231230094911 - Sat Dec 30 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231231111742 - Sun Dec 31 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20231231111742 - Sun Dec 31 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20240101205352 - Mon Jan 01 2024.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Daily Reflection/20240101205352 - Mon Jan 01 2024.json

# %% [markdown]
# # Import Health Journal

# %%
# Set this as the location where your Journal.json file is located
root = "/Volumes/External/01-01-2024_9-10-PM"
import_journal = os.path.join(root, 'Health Journal.json')

# Set this as the location where you want to export your journal entries
export_journal = os.path.join(root, 'Health Journal')

# Create the export folder if it doesn't exist
if not os.path.exists(export_journal):
    os.mkdir(export_journal)

# Read the journal file
with open(import_journal, 'r') as f:
    journal = json.load(f)

print(len(journal['entries']))

# Iterate through the journal entries
for entry in journal['entries']:
    create_obsidian_entry_from_day_one(root, entry, export_journal, tags = ['#healthjournal', '#dayoneimport'])
    time.sleep(1) # sleep for 1 second to avoid duplicate filenames
# Out:
# 10
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Health Journal/20181205214146 - Wed Dec 05 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Health Journal/20181205214146 - Wed Dec 05 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Health Journal/20181206233902 - Thu Dec 06 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Health Journal/20181206233902 - Thu Dec 06 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Health Journal/20181207090723 - Fri Dec 07 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Health Journal/20181207090723 - Fri Dec 07 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Health Journal/20181210232806 - Mon Dec 10 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Health Journal/20181210232806 - Mon Dec 10 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Health Journal/20181215110314 - Sat Dec 15 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Health Journal/20181215110314 - Sat Dec 15 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Health Journal/20181226110717 - Wed Dec 26 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Health Journal/20181226110717 - Wed Dec 26 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Health Journal/20190102013315 - Wed Jan 02 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Health Journal/20190102013315 - Wed Jan 02 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Health Journal/20190102013317 - Wed Jan 02 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Health Journal/20190102013317 - Wed Jan 02 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Health Journal/20190103214354 - Thu Jan 03 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Health Journal/20190103214354 - Thu Jan 03 2019.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Health Journal/20191130004035 - Sat Nov 30 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Health Journal/20191130004035 - Sat Nov 30 2019.json

# %% [markdown]
# # Import Gratitude Journal

# %%
# Set this as the location where your Journal.json file is located
root = "/Volumes/External/01-01-2024_9-10-PM"
import_journal = os.path.join(root, 'Gratitude Journal.json')

# Set this as the location where you want to export your journal entries
export_journal = os.path.join(root, 'Gratitude Journal')

# Create the export folder if it doesn't exist
if not os.path.exists(export_journal):
    os.mkdir(export_journal)

# Read the journal file
with open(import_journal, 'r') as f:
    journal = json.load(f)

print(len(journal['entries']))

# Iterate through the journal entries
for entry in journal['entries']:
    create_obsidian_entry_from_day_one(root, entry, export_journal, tags = ['#gratitudejournal', '#dayoneimport'])
    time.sleep(1) # sleep for 1 second to avoid duplicate filenames
# Out:
# 7
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Gratitude Journal/20181205213703 - Wed Dec 05 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Gratitude Journal/20181205213703 - Wed Dec 05 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Gratitude Journal/20181206233819 - Thu Dec 06 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Gratitude Journal/20181206233819 - Thu Dec 06 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Gratitude Journal/20181207210600 - Fri Dec 07 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Gratitude Journal/20181207210600 - Fri Dec 07 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Gratitude Journal/20181210232715 - Mon Dec 10 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Gratitude Journal/20181210232715 - Mon Dec 10 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Gratitude Journal/20181215110259 - Sat Dec 15 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Gratitude Journal/20181215110259 - Sat Dec 15 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Gratitude Journal/20181226110609 - Wed Dec 26 2018.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Gratitude Journal/20181226110609 - Wed Dec 26 2018.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Gratitude Journal/20190103214250 - Thu Jan 03 2019.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Gratitude Journal/20190103214250 - Thu Jan 03 2019.json

# %% [markdown]
# # Import Yearly Reflections

# %%
# Set this as the location where your Journal.json file is located
root = "/Volumes/External/01-01-2024_9-10-PM"
import_journal = os.path.join(root, 'Yearly Reflections.json')

# Set this as the location where you want to export your journal entries
export_journal = os.path.join(root, 'Yearly Reflections')

# Create the export folder if it doesn't exist
if not os.path.exists(export_journal):
    os.mkdir(export_journal)

# Read the journal file
with open(import_journal, 'r') as f:
    journal = json.load(f)

print(len(journal['entries']))

# Iterate through the journal entries
for entry in journal['entries']:
    create_obsidian_entry_from_day_one(root, entry, export_journal, tags = ['#yearlyreflection', '#dayoneimport'])
    time.sleep(1) # sleep for 1 second to avoid duplicate filenames
# Out:
# 2
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Yearly Reflections/20230101190025 - Sun Jan 01 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Yearly Reflections/20230101190025 - Sun Jan 01 2023.json
# Writing obsidian md file /Volumes/External/01-01-2024_9-10-PM/Yearly Reflections/20231231234818 - Sun Dec 31 2023.md
# Writing day one json file to /Volumes/External/01-01-2024_9-10-PM/Yearly Reflections/20231231234818 - Sun Dec 31 2023.json
